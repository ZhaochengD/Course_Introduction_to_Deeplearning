# %%
import glob
# import os
import cv2
from PIL import Image
import numpy as np
import random

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
torch.cuda.is_available()
# Out:
# True

# %%
root = 'D:/Jester/jester/20bn-jester-v1/*'
num_classes = 28
num_worker = 0
batch_size = 4
scales = [1, 1/2**(1/4), 1/2**(1/2), 1/2**(3/4), 1/2]
sample_size = 224
sample_duration = 16
rgb_mean = (114.7748/255, 107.7354/255, 99.4750/255)
rgb_std = (38.7568578/255, 37.88248729/255, 40.02898126/255)
lr = 0.01
momentum = 0.9
weight_decay = 5e-4

# %%
def load_all_path(root):
    video_dictionary = sorted(glob.glob(root))
    all_path = []
    for video_path in video_dictionary:
        file_list = sorted(glob.glob(video_path + '/*'))
        all_path.append(file_list)
    return all_path

# %%
all_path = load_all_path(root)
labels = np.genfromtxt('D:/Jester/jester-v1-labels.csv', delimiter=',', dtype=np.str)
labels.tolist()
# Out:
# ['Swiping Left',
#  'Swiping Right',
#  'Swiping Down',
#  'Swiping Up',
#  'Pushing Hand Away',
#  'Pulling Hand In',
#  'Sliding Two Fingers Left',
#  'Sliding Two Fingers Right',
#  'Sliding Two Fingers Down',
#  'Sliding Two Fingers Up',
#  'Pushing Two Fingers Away',
#  'Pulling Two Fingers In',
#  'Rolling Hand Forward',
#  'Rolling Hand Backward',
#  'Turning Hand Clockwise',
#  'Turning Hand Counterclockwise',
#  'Zooming In With Full Hand',
#  'Zooming Out With Full Hand',
#  'Zooming In With Two Fingers',
#  'Zooming Out With Two Fingers',
#  'Thumb Up',
#  'Thumb Down',
#  'Shaking Hand',
#  'Stop Sign',
#  'Drumming Fingers',
#  'No gesture',
#  'Doing other things']

# %%
class TemporalCrop(object):
    """Temporally crop the given frame indices at a random location or at the center location.
        size (int): Desired output size of the crop.
    """

    def __init__(self, size, mode):
        self.size = size
        self.mode = mode

    def __call__(self, path):
        """
        Args:
            paths (list): paths to be cropped.
        Returns:
            list: Cropped paths.
        """
        num_frames = len(path)
        
        if self.mode == 'random':
            if num_frames < self.size:
                pad_before = (self.size - num_frames)//2
                pad_after = self.size - num_frames - pad_before
                new_path = [path[0]]*pad_before + path + [path[-1]]*pad_after
            else:
                begin_index = random.randint(0, num_frames - self.size)
                end_index = begin_index + self.size
                new_path = path[begin_index:end_index]
        else:
            if num_frames < self.size:
                pad_before = (self.size - num_frames)//2
                pad_after = self.size - num_frames - pad_before
                new_path = [path[0]]*pad_before + path + [path[-1]]*pad_after
            else:
                begin_index = (num_frames - self.size)//2
                end_index = begin_index + self.size
                new_path = path[begin_index:end_index]
        
        return new_path

    
class MultiScaleRandomCrop(object):

    def __init__(self, scales, size, interpolation=Image.BILINEAR):
        self.scales = scales
        self.size = size
        self.interpolation = interpolation
        
    @staticmethod
    def get_random_param(self):
        self.scale = self.scales[random.randint(0, len(self.scales) - 1)]
        self.topleft_x = random.random()
        self.topleft_y = random.random()

    def __call__(self, img):
        image_width, image_height = _get_image_size(img)
        min_length = min(image_width, image_height)
        crop_size = int(min_length * self.scale)

        topleft_x = self.topleft_x * (image_width - crop_size)
        topleft_y = self.topleft_y * (image_height - crop_size)
        bottomright_x = topleft_x + crop_size
        bottomright_y = topleft_x + crop_size

        img = F.resized_crop(img, topleft_x, topleft_y, bottomright_x, bottomright_y, self.size, self.interpolation)

        return img

# class SpatialElasticDisplacement(object):

#     def __init__(self, sigma=2.0, alpha=1.0, order=0, cval=0, mode="constant"):
#         self.alpha = alpha
#         self.sigma = sigma
#         self.order = order
#         self.cval = cval
#         self.mode = mode
    
#         @staticmethod
#     def get_random_param(self):
#         self.p = random.random()
        
#     def __call__(self, img):
#         if self.p < 0.50:
#             is_L = False
#             is_PIL = isinstance(img, Image.Image)
            
#             if is_PIL:
#                 img = np.asarray(img, dtype=np.uint8)
#             if len(img.shape) == 2:
#                 is_L = True
#                 img = np.reshape(img, img.shape + (1,))  

#             image = img
#             image_first_channel = np.squeeze(image[..., 0])
#             indices_x, indices_y = self._generate_indices(image_first_channel.shape, alpha=self.alpha, sigma=self.sigma)
#             ret_image = (self._map_coordinates(
#                 image,
#                 indices_x,
#                 indices_y,
#                 order=self.order,
#                 cval=self.cval,
#                 mode=self.mode))

#             if  is_PIL:
#                 if is_L:
#                     return Image.fromarray(ret_image.reshape(ret_image.shape[:2]), mode= 'L')
#                 else:
#                     return Image.fromarray(ret_image)
#             else:
#                 return ret_image
#         else:
#             return img

#     def _generate_indices(self, shape, alpha, sigma):
#         assert (len(shape) == 2),"shape: Should be of size 2!"
#         dx = scipy.ndimage.gaussian_filter((np.random.rand(*shape) * 2 - 1), sigma, mode="constant", cval=0) * alpha
#         dy = scipy.ndimage.gaussian_filter((np.random.rand(*shape) * 2 - 1), sigma, mode="constant", cval=0) * alpha

#         x, y = np.meshgrid(np.arange(shape[0]), np.arange(shape[1]), indexing='ij')
#         return np.reshape(x+dx, (-1, 1)), np.reshape(y+dy, (-1, 1))

#     def _map_coordinates(self, image, indices_x, indices_y, order=1, cval=0, mode="constant"):
#         assert (len(image.shape) == 3),"image.shape: Should be of size 3!"
#         result = np.copy(image)
#         height, width = image.shape[0:2]
#         for c in range(image.shape[2]):
#             remapped_flat = scipy.ndimage.interpolation.map_coordinates(
#                 image[..., c],
#                 (indices_x, indices_y),
#                 order=order,
#                 cval=cval,
#                 mode=mode
#             )
#             remapped = remapped_flat.reshape((height, width))
#             result[..., c] = remapped
#         return result

# %%
def read_video(paths, mode):
    all_image = []
    temporal_transform = TemporalCrop(sample_duration, mode)
    if mode == 'train':
        spatial_transform = transforms.Compose([
            transforms.ToPILImage(),
            MultiScaleRandomCrop(scales, sample_size),
    #         SpatialElasticDisplacement(),
            transforms.ToTensor(),
            transforms.Normalize(rgb_mean, rgb_std)
        ])
    else:
        spatial_transform = transforms.Compose([
            transforms.ToPILImage(),
            transforms.Resize(sample_size),
            transforms.CenterCrop(sample_size),
            transforms.ToTensor(),
            transforms.Normalize(rgb_mean, rgb_std)
        ])
                
    new_paths = temporal_transform(paths)
    for path in new_paths:
        image = cv2.imread(path)
        image = spatial_transform(image)
        all_image.append(image)
    video = np.stack(all_image).transpose(1,0,2,3)
    return video

# %%
class Dataset(Dataset):
    def __init__(self, all_path, x, y, mode):
        self.length = len(x)
        self.all_path = all_path
        self.x = x
        self.y = y
        self.mode = mode
    
    def __len__(self):
        return(self.length)
    
    def __getitem__(self, index):
        if self.mode == 'train':
            x = read_video(self.all_path[int(self.x[index,0])-1], 'random')
            y = int(np.argwhere(self.y == self.x[index,1]))
            return torch.from_numpy(x), torch.tensor(y)
        elif self.mode == 'valid':
            x = read_video(self.all_path[int(self.x[index,0])-1], 'center')
            y = int(np.argwhere(self.y == self.x[index,1]))
            return torch.from_numpy(x), torch.tensor(y)
        else:
            x = read_video(self.all_path[int(self.x[index])-1], 'center')
            return torch.from_numpy(x)

# %%
train = np.genfromtxt('D:/Jester/jester-v1-train.csv', delimiter=',', dtype=np.str)    
train_data = Dataset(all_path, train, labels, 'train')
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True, num_workers=num_worker, pin_memory=True)

# %%
valid = np.genfromtxt('D:/Jester/jester-v1-validation.csv', delimiter=',', dtype=np.str)
valid_data = Dataset(all_path, valid, labels, 'valid')
valid_loader = DataLoader(valid_data, batch_size=batch_size, shuffle=False, num_workers=num_worker, pin_memory=True)

# %%
test = np.genfromtxt('D:/Jester/jester-v1-test.csv', delimiter=',', dtype=np.str)
test_data = Dataset(all_path, test, labels, 'test')
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False, num_workers=num_worker, pin_memory=True)

# %%
# for i, (data, target) in enumerate(train_loader):
#     print(data.shape)

# %%
# def get_training_set(opt, spatial_transform, temporal_transform,
#                      target_transform):
#     assert opt.dataset in ['jester', 'egogesture', 'nv']

#     if opt.train_validate:
#         subset = ['training', 'validation']
#     else:
#         subset = 'training'
#     if opt.dataset == 'jester':
#         training_data = Jester(
#             opt.video_path,
#             opt.annotation_path,
#             subset,
#             spatial_transform=spatial_transform,
#             temporal_transform=temporal_transform,
#             target_transform=target_transform,
#             sample_duration=opt.sample_duration,
#             modality=opt.modality)
#     elif opt.dataset == 'egogesture':
#         training_data = EgoGesture(
#             opt.video_path,
#             opt.annotation_path,
#             subset,
#             spatial_transform=spatial_transform,
#             temporal_transform=temporal_transform,
#             target_transform=target_transform,
#             sample_duration=opt.sample_duration,
#             modality=opt.modality)
#     elif opt.dataset == 'nv':
#         training_data = NV(
#             opt.video_path,
#             opt.annotation_path,
#             subset,
#             spatial_transform=spatial_transform,
#             temporal_transform=temporal_transform,
#             target_transform=target_transform,
#             sample_duration=opt.sample_duration,
#             modality=opt.modality)
#     return training_data


# def get_validation_set(opt, spatial_transform, temporal_transform,
#                        target_transform):
#     assert opt.dataset in ['jester', 'egogesture', 'nv']

#     if opt.dataset == 'jester':
#         validation_data = Jester(
#             opt.video_path,
#             opt.annotation_path,
#             'validation',
#             opt.n_val_samples,
#             spatial_transform,
#             temporal_transform,
#             target_transform,
#             modality=opt.modality,
#             sample_duration=opt.sample_duration)
#     elif opt.dataset == 'egogesture':
#         validation_data = EgoGesture(
#             opt.video_path,
#             opt.annotation_path,
#             'validation',
#             opt.n_val_samples,
#             spatial_transform,
#             temporal_transform,
#             target_transform,
#             modality=opt.modality,
#             sample_duration=opt.sample_duration)
#     elif opt.dataset == 'nv':
#         validation_data = NV(
#             opt.video_path,
#             opt.annotation_path,
#             'validation',
#             spatial_transform=spatial_transform,
#             temporal_transform=temporal_transform,
#             target_transform=target_transform,
#             sample_duration=opt.sample_duration,
#             modality=opt.modality)
#     return validation_data

# %%
class ResNeXtBottleneck(nn.Module):
    def __init__(self, in_channels, cardinality=32, width=4, stride=1):
        super(ResNeXtBottleneck, self).__init__()
        channels = cardinality*width
        out_channels = 2*channels
        
        self.net = nn.Sequential(
            nn.BatchNorm3d(in_channels),
            nn.PReLU(),
            nn.Conv3d(in_channels, channels, kernel_size=1, bias=False),
            nn.BatchNorm3d(channels),
            nn.PReLU(),
            nn.Conv3d(channels, channels, kernel_size=3, stride=stride, padding=1, groups=cardinality, bias=False),
            nn.BatchNorm3d(channels),
            nn.PReLU(),
            nn.Conv3d(channels, out_channels, kernel_size=1, bias=False)
        )

        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.BatchNorm3d(in_channels),
                nn.PReLU(),
                nn.Conv3d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False)
            )
        else:
            self.shortcut = nn.Identity()
            
    def forward(self, x):
        out = self.net(x)
        out += self.shortcut(x)
        return out
    
    
class ResNeXt(nn.Module):
    def __init__(self, block, num_blocks, cardinality, width, num_class):
        super(ResNeXt, self).__init__()
        self.cardinality = cardinality
        self.width = width
        self.in_channels = 64

        self.feature_detector = nn.Sequential(
            nn.Conv3d(3, 64, kernel_size=(3,7,7), stride=(1,2,2), padding=(1,3,3), bias=False),
            nn.MaxPool3d(kernel_size=3, stride=2, padding=1),
            self.stack_blocks(block, num_blocks[0], stride=1),
            self.stack_blocks(block, num_blocks[1], stride=2),
            self.stack_blocks(block, num_blocks[2], stride=2),
            self.stack_blocks(block, num_blocks[3], stride=2),
            nn.AvgPool3d((1,7,7)),
            nn.Dropout3d(0.5),
            nn.Flatten()
        )
        
        self.classifier = nn.Linear(2048,num_class)
        
        for layer in self.modules():
            if isinstance(layer, nn.Conv3d):
                nn.init.kaiming_normal_(layer.weight, mode='fan_out', nonlinearity='relu')
            elif isinstance(layer, nn.BatchNorm3d):
                nn.init.constant_(layer.weight, val=1.0)
                nn.init.constant_(layer.bias, val=0.0)
            elif isinstance(layer, nn.Linear):
                nn.init.kaiming_normal_(layer.weight, mode='fan_out', nonlinearity='relu')
                nn.init.constant_(layer.bias, val=0.0)
                
    def stack_blocks(self, block, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channels, self.cardinality, self.width, stride))
            self.in_channels = 2*self.cardinality*self.width
        self.width *= 2
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.feature_detector(x)
        out = self.classifier(out)
        return out

# %%
# model = torch.hub.load('pytorch/vision:v0.5.0', 'resnext50_32x4d', pretrained=True)
model = ResNeXt(ResNeXtBottleneck, [3,4,6,3], cardinality=32, width=4, num_class=num_classes)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum, weight_decay=weight_decay, nesterov=True)
scheduler = ReduceLROnPlateau(optimizer, mode = 'min', factor=0.1, patience=2)
device = torch.device("cuda")
model.to(device)
# Out:
# ResNeXt(
#   (feature_detector): Sequential(
#     (0): Conv3d(3, 64, kernel_size=(3, 7, 7), stride=(1, 2, 2), padding=(1, 3, 3), bias=False)
#     (1): MaxPool3d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (2): Sequential(
#       (0): ResNeXtBottleneck(
#         (net): Sequential(
#           (0): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): PReLU(num_parameters=1)
#           (2): Conv3d(64, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (3): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): PReLU(num_parameters=1)
#           (5): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=32, bias=False)
#           (6): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): PReLU(num_parameters=1)
#           (8): Conv3d(128, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         )
#         (shortcut): Sequential(
#           (0): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): PReLU(num_parameters=1)
#           (2): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         )
#       )
#       (1): ResNeXtBottleneck(
#         (net): Sequential(
#           (0): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): PReLU(num_parameters=1)
#           (2): Conv3d(256, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (3): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): PReLU(num_parameters=1)
#           (5): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=32, bias=False)
#           (6): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): PReLU(num_parameters=1)
#           (8): Conv3d(128, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         )
#         (shortcut): Identity()
#       )
#       (2): ResNeXtBottleneck(
#         (net): Sequential(
#           (0): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): PReLU(num_parameters=1)
#           (2): Conv3d(256, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (3): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): PReLU(num_parameters=1)
#           (5): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=32, bias=False)
#           (6): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): PReLU(num_parameters=1)
#           (8): Conv3d(128, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         )
#         (shortcut): Identity()
#       )
#     )
#     (3): Sequential(
#       (0): ResNeXtBottleneck(
#         (net): Sequential(
#           (0): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): PReLU(num_parameters=1)
#           (2): Conv3d(256, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (3): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): PReLU(num_parameters=1)
#           (5): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), groups=32, bias=False)
#           (6): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): PReLU(num_parameters=1)
#           (8): Conv3d(256, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         )
#         (shortcut): Sequential(
#           (0): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): PReLU(num_parameters=1)
#           (2): Conv3d(256, 512, kernel_size=(1, 1, 1), stride=(2, 2, 2), bias=False)
#         )
#       )
#       (1): ResNeXtBottleneck(
#         (net): Sequential(
#           (0): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): PReLU(num_parameters=1)
#           (2): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (3): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): PReLU(num_parameters=1)
#           (5): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=32, bias=False)
#           (6): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): PReLU(num_parameters=1)
#           (8): Conv3d(256, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         )
#         (shortcut): Identity()
#       )
#       (2): ResNeXtBottleneck(
#         (net): Sequential(
#           (0): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): PReLU(num_parameters=1)
#           (2): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (3): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): PReLU(num_parameters=1)
#           (5): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=32, bias=False)
#           (6): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): PReLU(num_parameters=1)
#           (8): Conv3d(256, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         )
#         (shortcut): Identity()
#       )
#       (3): ResNeXtBottleneck(
#         (net): Sequential(
#           (0): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): PReLU(num_parameters=1)
#           (2): Conv3d(512, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (3): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): PReLU(num_parameters=1)
#           (5): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=32, bias=False)
#           (6): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): PReLU(num_parameters=1)
#           (8): Conv3d(256, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         )
#         (shortcut): Identity()
#       )
#     )
#     (4): Sequential(
#       (0): ResNeXtBottleneck(
#         (net): Sequential(
#           (0): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): PReLU(num_parameters=1)
#           (2): Conv3d(512, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (3): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): PReLU(num_parameters=1)
#           (5): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), groups=32, bias=False)
#           (6): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): PReLU(num_parameters=1)
#           (8): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         )
#         (shortcut): Sequential(
#           (0): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): PReLU(num_parameters=1)
#           (2): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(2, 2, 2), bias=False)
#         )
#       )
#       (1): ResNeXtBottleneck(
#         (net): Sequential(
#           (0): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): PReLU(num_parameters=1)
#           (2): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (3): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): PReLU(num_parameters=1)
#           (5): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=32, bias=False)
#           (6): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): PReLU(num_parameters=1)
#           (8): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         )
#         (shortcut): Identity()
#       )
#       (2): ResNeXtBottleneck(
#         (net): Sequential(
#           (0): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): PReLU(num_parameters=1)
#           (2): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (3): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): PReLU(num_parameters=1)
#           (5): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=32, bias=False)
#           (6): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): PReLU(num_parameters=1)
#           (8): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         )
#         (shortcut): Identity()
#       )
#       (3): ResNeXtBottleneck(
#         (net): Sequential(
#           (0): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): PReLU(num_parameters=1)
#           (2): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (3): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): PReLU(num_parameters=1)
#           (5): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=32, bias=False)
#           (6): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): PReLU(num_parameters=1)
#           (8): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         )
#         (shortcut): Identity()
#       )
#       (4): ResNeXtBottleneck(
#         (net): Sequential(
#           (0): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): PReLU(num_parameters=1)
#           (2): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (3): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): PReLU(num_parameters=1)
#           (5): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=32, bias=False)
#           (6): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): PReLU(num_parameters=1)
#           (8): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         )
#         (shortcut): Identity()
#       )
#       (5): ResNeXtBottleneck(
#         (net): Sequential(
#           (0): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): PReLU(num_parameters=1)
#           (2): Conv3d(1024, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (3): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): PReLU(num_parameters=1)
#           (5): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=32, bias=False)
#           (6): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): PReLU(num_parameters=1)
#           (8): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         )
#         (shortcut): Identity()
#       )
#     )
#     (5): Sequential(
#       (0): ResNeXtBottleneck(
#         (net): Sequential(
#           (0): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): PReLU(num_parameters=1)
#           (2): Conv3d(1024, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (3): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): PReLU(num_parameters=1)
#           (5): Conv3d(1024, 1024, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), groups=32, bias=False)
#           (6): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): PReLU(num_parameters=1)
#           (8): Conv3d(1024, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         )
#         (shortcut): Sequential(
#           (0): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): PReLU(num_parameters=1)
#           (2): Conv3d(1024, 2048, kernel_size=(1, 1, 1), stride=(2, 2, 2), bias=False)
#         )
#       )
#       (1): ResNeXtBottleneck(
#         (net): Sequential(
#           (0): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): PReLU(num_parameters=1)
#           (2): Conv3d(2048, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (3): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): PReLU(num_parameters=1)
#           (5): Conv3d(1024, 1024, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=32, bias=False)
#           (6): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): PReLU(num_parameters=1)
#           (8): Conv3d(1024, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         )
#         (shortcut): Identity()
#       )
#       (2): ResNeXtBottleneck(
#         (net): Sequential(
#           (0): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): PReLU(num_parameters=1)
#           (2): Conv3d(2048, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (3): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): PReLU(num_parameters=1)
#           (5): Conv3d(1024, 1024, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), groups=32, bias=False)
#           (6): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (7): PReLU(num_parameters=1)
#           (8): Conv3d(1024, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#         )
#         (shortcut): Identity()
#       )
#     )
#     (6): AvgPool3d(kernel_size=(1, 7, 7), stride=(1, 7, 7), padding=0)
#     (7): Dropout3d(p=0.5, inplace=False)
#     (8): Flatten()
#   )
#   (classifier): Linear(in_features=2048, out_features=28, bias=True)
# )

# %%
def train_epoch(model, train_loader, criterion, optimizer):
    model.train()

    running_loss = 0.0
    total_predictions = 0.0
    correct_predictions = 0.0
    
    for i, data in enumerate(train_loader, 0):
        inputs, labels = data
        inputs = inputs.to(device)
        labels = labels.to(device)
        
        optimizer.zero_grad()

        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total_predictions += labels.size(0)
        
        correct_predictions += (predicted == labels).sum().item()
        loss = criterion(outputs, labels)
        running_loss += loss.item()
        print(i, loss)
        loss.backward()
        optimizer.step()

    running_loss /= len(train_loader)
    acc = (correct_predictions/total_predictions)*100.0
    print('Training Loss: ', running_loss)
    print('Training Accuracy: ', acc, '%')
    return running_loss, acc

# %%
def test_model(model, test_loader, criterion):
    with torch.no_grad():
        model.eval()

        running_loss = 0.0
        total_predictions = 0.0
        correct_predictions = 0.0
        
        for i, data in enumerate(test_loader, 0):
            inputs, labels = data
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)

            _, predicted = torch.max(outputs.data, 1)
            total_predictions += labels.size(0)
            correct_predictions += (predicted == labels).sum().item()

            loss = criterion(outputs, labels).detach()
            running_loss += loss.item()
            
        running_loss /= len(test_loader)
        acc = (correct_predictions/total_predictions)*100.0
        print('Validation Loss: ', running_loss)
        print('Validation Accuracy: ', acc, '%')
        return running_loss, acc

# %%
n_epochs = 100
Train_loss = []
Train_acc = []
Valid_loss = []
Valid_acc = []
num_no_improve = 0
for i in range(n_epochs):
    train_loss, train_acc = train_epoch(model, train_loader, criterion, optimizer)
    valid_loss, valid_acc = test_model(model, valid_loader, criterion)
    Train_acc.append(train_acc)
    Train_loss.append(train_loss)
    Valid_loss.append(valid_loss)
    scheduler.step(valid_loss)
    print('='*40)

    if i == 0:
        torch.save(model.state_dict(), 'project.pth')
    else:
        if test_acc > max(Test_acc):
            torch.save(model.state_dict(), 'project.pth')
            num_no_improve = 0
        else:
            num_no_improve += 1
    Valid_acc.append(valid_acc)
    
    training_loss = np.array(Train_loss).reshape(-1,1)
    training_acc = np.array(Train_acc).reshape(-1,1)
    validation_loss = np.array(Valid_loss).reshape(-1,1)
    validation_acc = np.array(Valid_acc).reshape(-1,1)
    result = np.concatenate([training_loss, training_acc, validation_loss, validation_acc]).T
    np.savetxt('result_project.csv', result, delimiter=',', fmt='%1.5f', header='training_loss,training_acc,validation_loss,validation_acc', comments='')
    
    if num_no_improve >= 10:
        break
# Out:
# 0 tensor(27.6849, device='cuda:0', grad_fn=<NllLossBackward>)
# 1 tensor(243.1723, device='cuda:0', grad_fn=<NllLossBackward>)
# 2 tensor(282.3637, device='cuda:0', grad_fn=<NllLossBackward>)
# 3 tensor(1376.7660, device='cuda:0', grad_fn=<NllLossBackward>)
# 4 tensor(1202.6620, device='cuda:0', grad_fn=<NllLossBackward>)
# 5 tensor(3354.1289, device='cuda:0', grad_fn=<NllLossBackward>)
# 6 tensor(26028.6914, device='cuda:0', grad_fn=<NllLossBackward>)
# 7 tensor(135842.5938, device='cuda:0', grad_fn=<NllLossBackward>)
# 8 tensor(4014499.7500, device='cuda:0', grad_fn=<NllLossBackward>)
# 9 tensor(2.1298e+10, device='cuda:0', grad_fn=<NllLossBackward>)
# 10 tensor(1.4256e+22, device='cuda:0', grad_fn=<NllLossBackward>)
# 11 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 12 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 13 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 14 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 15 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 16 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 17 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 18 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 19 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 20 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 21 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 22 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 23 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 24 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 25 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 26 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 27 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 28 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 29 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 30 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 31 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 32 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 33 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 34 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 35 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 36 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 37 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 38 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 39 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 40 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 41 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 42 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 43 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 44 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 45 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 46 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 47 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 48 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 49 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 50 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 51 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 52 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 53 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 54 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 55 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 56 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 57 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 58 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 59 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 60 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 61 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 62 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 63 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 64 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 65 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 66 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 67 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 68 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 69 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 70 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 71 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 72 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 73 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 74 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 75 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 76 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 77 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 78 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 79 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 80 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 81 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 82 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 83 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 84 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 85 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 86 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 87 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 88 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 89 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 90 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 91 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 92 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 93 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 94 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 95 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 96 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 97 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 98 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 99 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 100 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 101 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 102 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 103 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 104 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 105 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 106 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 107 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 108 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 109 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 110 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 111 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 112 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 113 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 114 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 115 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 116 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 117 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 118 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 119 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 120 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 121 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 122 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 123 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 124 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 125 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 126 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 127 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 128 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 129 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 130 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 131 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 132 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 133 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 134 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 135 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 136 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 137 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 138 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 139 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 140 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 141 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 142 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 143 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 144 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 145 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 146 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 147 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 148 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 149 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 150 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 151 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 152 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 153 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 154 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 155 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 156 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 157 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 158 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 159 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 160 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 161 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 162 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 163 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 164 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 165 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 166 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 167 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 168 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 169 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 170 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 171 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 172 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 173 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 174 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 175 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 176 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 177 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 178 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 179 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 180 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 181 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 182 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 183 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 184 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 185 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 186 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 187 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 188 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 189 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 190 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 191 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 192 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 193 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 194 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 195 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 196 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 197 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 198 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 199 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 200 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 201 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 202 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 203 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 204 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 205 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 206 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 207 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 208 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 209 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 210 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 211 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 212 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 213 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 214 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 215 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 216 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 217 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 218 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 219 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 220 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 221 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 222 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 223 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 224 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 225 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 226 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 227 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 228 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 229 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 230 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 231 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 232 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 233 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 234 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 235 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 236 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 237 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 238 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 239 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 240 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 241 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 242 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 243 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 244 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 245 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 246 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 247 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 248 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 249 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 250 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 251 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 252 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 253 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 254 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 255 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 256 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 257 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 258 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 259 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 260 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 261 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 262 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 263 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 264 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 265 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 266 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 267 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 268 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 269 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 270 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 271 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 272 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 273 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 274 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 275 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 276 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 277 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 278 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 279 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 280 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 281 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 282 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 283 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 284 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 285 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 286 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 287 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 288 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 289 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 290 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 291 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 292 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 293 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 294 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 295 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 296 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 297 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 298 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 299 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 300 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 301 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 302 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 303 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 304 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 305 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 306 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 307 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 308 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 309 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 310 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 311 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 312 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 313 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 314 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 315 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 316 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 317 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 318 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 319 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 320 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 321 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 322 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 323 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 324 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 325 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 326 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 327 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 328 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 329 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 330 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 331 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 332 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 333 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 334 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 335 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 336 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 337 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 338 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 339 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 340 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 341 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 342 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 343 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 344 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 345 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 346 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 347 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 348 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 349 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 350 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 351 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 352 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 353 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 354 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 355 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 356 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 357 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 358 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 359 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 360 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 361 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 362 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 363 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 364 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 365 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 366 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 367 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 368 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 369 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 370 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 371 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 372 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 373 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 374 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 375 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 376 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 377 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 378 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 379 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 380 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 381 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 382 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 383 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 384 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 385 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 386 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 387 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 388 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 389 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 390 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 391 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 392 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 393 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 394 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 395 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 396 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 397 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 398 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 399 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 400 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 401 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 402 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 403 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 404 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 405 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 406 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 407 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 408 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 409 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 410 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 411 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 412 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 413 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 414 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 415 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 416 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 417 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 418 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 419 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 420 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 421 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 422 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 423 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 424 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 425 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 426 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 427 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 428 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 429 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 430 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 431 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 432 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 433 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 434 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 435 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 436 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 437 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 438 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 439 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 440 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 441 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 442 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 443 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 444 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 445 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 446 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 447 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 448 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 449 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 450 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 451 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 452 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 453 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 454 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 455 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 456 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 457 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 458 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 459 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 460 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 461 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 462 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 463 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 464 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 465 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 466 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 467 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 468 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 469 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 470 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 471 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 472 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 473 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 474 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 475 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 476 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 477 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 478 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 479 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 480 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 481 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 482 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 483 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 484 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 485 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 486 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 487 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 488 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 489 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 490 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 491 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 492 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 493 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 494 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 495 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 496 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 497 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 498 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 499 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 500 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 501 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 502 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 503 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 504 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 505 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 506 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 507 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 508 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 509 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 510 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 511 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 512 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 513 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 514 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 515 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 516 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 517 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 518 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 519 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 520 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 521 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 522 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 523 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 524 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 525 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 526 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 527 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 528 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 529 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 530 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 531 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 532 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 533 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 534 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 535 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 536 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 537 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 538 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 539 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 540 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 541 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 542 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 543 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 544 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 545 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 546 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 547 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 548 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 549 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 550 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 551 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 552 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 553 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 554 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 555 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 556 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 557 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 558 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 559 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 560 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 561 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 562 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 563 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 564 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 565 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 566 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 567 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 568 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 569 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 570 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 571 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 572 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 573 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 574 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 575 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 576 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 577 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 578 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 579 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 580 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 581 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 582 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 583 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 584 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 585 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 586 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 587 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 588 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 589 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 590 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 591 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 592 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 593 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 594 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 595 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 596 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 597 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 598 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 599 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 600 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 601 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 602 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 603 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 604 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 605 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 606 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 607 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 608 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 609 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 610 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 611 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 612 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 613 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 614 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 615 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 616 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 617 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 618 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 619 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 620 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 621 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 622 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 623 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 624 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 625 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 626 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 627 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 628 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 629 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 630 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 631 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 632 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 633 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 634 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 635 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 636 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 637 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 638 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 639 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 640 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 641 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 642 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 643 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 644 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 645 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 646 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 647 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 648 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 649 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 650 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 651 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 652 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 653 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 654 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 655 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 656 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 657 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 658 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 659 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 660 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 661 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 662 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 663 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 664 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 665 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 666 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 667 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 668 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 669 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 670 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 671 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 672 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 673 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 674 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 675 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 676 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 677 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 678 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 679 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 680 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 681 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 682 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 683 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 684 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 685 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 686 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 687 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 688 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 689 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 690 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 691 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 692 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 693 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 694 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 695 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 696 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 697 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 698 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 699 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 700 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 701 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 702 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 703 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 704 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 705 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 706 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 707 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 708 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 709 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 710 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 711 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 712 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 713 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 714 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 715 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 716 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 717 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 718 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 719 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 720 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 721 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 722 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 723 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 724 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 725 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 726 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 727 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 728 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 729 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 730 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 731 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 732 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 733 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 734 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 735 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 736 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 737 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 738 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 739 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 740 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 741 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 742 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 743 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 744 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 745 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 746 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 747 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 748 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 749 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 750 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 751 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 752 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 753 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 754 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 755 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 756 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 757 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 758 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 759 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 760 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 761 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 762 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 763 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 764 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 765 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 766 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 767 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 768 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 769 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 770 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 771 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 772 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 773 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 774 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 775 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 776 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 777 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 778 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 779 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 780 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 781 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 782 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 783 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 784 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 785 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 786 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 787 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 788 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 789 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 790 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 791 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 792 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 793 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 794 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 795 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 796 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 797 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 798 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 799 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 800 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 801 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 802 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 803 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 804 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 805 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 806 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 807 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 808 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 809 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 810 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 811 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 812 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 813 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 814 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 815 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 816 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 817 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 818 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 819 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 820 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 821 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 822 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 823 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 824 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 825 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 826 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 827 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 828 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 829 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 830 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 831 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 832 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 833 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 834 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 835 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 836 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 837 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 838 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 839 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 840 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 841 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 842 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 843 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 844 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 845 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 846 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 847 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 848 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 849 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 850 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 851 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 852 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 853 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 854 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 855 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 856 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 857 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 858 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 859 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 860 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 861 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 862 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 863 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 864 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 865 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 866 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 867 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 868 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 869 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 870 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 871 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 872 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 873 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 874 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 875 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 876 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 877 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 878 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 879 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 880 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 881 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 882 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 883 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 884 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 885 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 886 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 887 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 888 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 889 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 890 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 891 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 892 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 893 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 894 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 895 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 896 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 897 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 898 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 899 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 900 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 901 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 902 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 903 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 904 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 905 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 906 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 907 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 908 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 909 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 910 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 911 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 912 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 913 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 914 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 915 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 916 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 917 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 918 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 919 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 920 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 921 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 922 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 923 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 924 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 925 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 926 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 927 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 928 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 929 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 930 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 931 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 932 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 933 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 934 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 935 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 936 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 937 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 938 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 939 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 940 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 941 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 942 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 943 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 944 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 945 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 946 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 947 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 948 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 949 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 950 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 951 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 952 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 953 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 954 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 955 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 956 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 957 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 958 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 959 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 960 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 961 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 962 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 963 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 964 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 965 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 966 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 967 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 968 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 969 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 970 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 971 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 972 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 973 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 974 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 975 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 976 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 977 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 978 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 979 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 980 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 981 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 982 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 983 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 984 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 985 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 986 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 987 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 988 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 989 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 990 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 991 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 992 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 993 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 994 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 995 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 996 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 997 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 998 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 999 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1000 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1001 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1002 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1003 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1004 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1005 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1006 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1007 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1008 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1009 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1010 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1011 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1012 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1013 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1014 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1015 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1016 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1017 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1018 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1019 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1020 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1021 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1022 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1023 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1024 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1025 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1026 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1027 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1028 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1029 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1030 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1031 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1032 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1033 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1034 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1035 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1036 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1037 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1038 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
# 1039 tensor(nan, device='cuda:0', grad_fn=<NllLossBackward>)
